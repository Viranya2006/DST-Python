# %% [markdown]
# Python List

# %%
fruitlist = {"apple","banana","orange","mango"}
print(fruitlist)

#get the length of the list
print(len(fruitlist))

for x in fruitlist:
    print (x)

    tupleA = ("banana","mango",53,12.5,False)
    print(tupleA)

    print (type (tupleA))
    listfromtupleA=list(tupleA)
print(listfromtupleA)
print (type(listfromtupleA))
listfromtupleA.append("ORANGE")
print(listfromtupleA)
tuplefromlist =tuple (listfromtupleA)
print (tuplefromlist)

fruitset = {"apple","banana","cherry"}
print(fruitset)

setA= {"apple",35,False,True,'Nimali'}
print(setA)
print(len (setA))
# Out:
# {'apple', 'orange', 'mango', 'banana'}
# 4
# apple
# ('banana', 'mango', 53, 12.5, False)
# <class 'tuple'>
# orange
# ('banana', 'mango', 53, 12.5, False)
# <class 'tuple'>
# mango
# ('banana', 'mango', 53, 12.5, False)
# <class 'tuple'>
# banana
# ('banana', 'mango', 53, 12.5, False)
# <class 'tuple'>
# ['banana', 'mango', 53, 12.5, False]
# <class 'list'>
# ['banana', 'mango', 53, 12.5, False, 'ORANGE']
# ('banana', 'mango', 53, 12.5, False, 'ORANGE')
# {'apple', 'cherry', 'banana'}
# {'apple', False, True, 35, 'Nimali'}
# 5

# %% [markdown]
# Dictonary

# %%
dictA = {
    "brand" : "Ferrari",
    "model" : "458",
    "year" : 2011
}

print(dictA)
# Out:
# {'brand': 'Ferrari', 'model': '458', 'year': 2011}

# %%
dictB = {
    "brand" : "Audi",
    "model" : "R8",
    "year" : 2007,
    "year" : 2011

}

print(dictB)
# Out:
# {'brand': 'Audi', 'model': 'R8', 'year': 2011}

# %%
dictC = {
    "brand" : "Porsche",
    "model" : "911 turbo s",
    "year" : 2026,
    "clour" : "miami blue"

}

print(dictC)
# Out:
# {'brand': 'Porsche', 'model': '911 turbo s', 'year': 2026, 'clour': 'miami blue'}

# %%
dictC = {
    "brand" : "Porsche",
    "model" : "911 turbo s",
    "year" : 2026,
    "clour" : "miami blue"

}
print(len(dictC))
print(dictC["clour"])
dictC.update({"year":2000})
print(dictC)

# %%
#add items to a dictionary

dictC["Engine"] = "5000cc"
print(dictC)

# %%
for x in dictC.keys():
    print(x)

# %%
for x,y in dictC.items():
    print(x,y)

# %% [markdown]
# Data Frames

# %%
import pandas as pd
data = {
    "calories": [250, 300, 4320],
    "duration": [34, 50, 69]
}

df = pd.DataFrame(data)
print(df)

# %%
print(df.loc[0])

# %%
print(df.loc[1])

# %%
carsalesDF = pd.read_csv("car-sales.csv")
#print(carsalesDF)
print(carsalesDF.head(5))
print(carsalesDF.tail(5))
